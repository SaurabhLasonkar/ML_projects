# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# **Null values :**

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# **There is no null values in dataset**

# %% [markdown]
# **Dataset information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# **Descriptive Statistics**

# %%
df.describe().T.head()
# Out:
#          count          mean           std        min           25%  \
# Time  284807.0  9.481386e+04  47488.145955   0.000000  54201.500000
# V1    284807.0  1.168375e-15      1.958696 -56.407510     -0.920373
# V2    284807.0  3.416908e-16      1.651309 -72.715728     -0.598550
# V3    284807.0 -1.379537e-15      1.516255 -48.325589     -0.890365
# V4    284807.0  2.074095e-15      1.415869  -5.683171     -0.848640
#
#                50%            75%            max
# Time  84692.000000  139320.500000  172792.000000
# V1        0.018109       1.315642       2.454930
# V2        0.065486       0.803724      22.057729
# V3        0.179846       1.027196       9.382558
# V4       -0.019847       0.743341      16.875344

# %%
df.shape
# Out:
# (284807, 31)

# %%
print('There are {} rows and {} columns'.format(df.shape[0],df.shape[1]))
# Out:
# There are 284807 rows and 31 columns

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %% [markdown]
# **Fraud cases And Valid cases**

# %%
fraud_cases=len(df[df['Class']==1])

# %%
print('Number of Fraud cases : {}'.format(fraud_cases))
# Out:
# Number of Fraud cases : 492

# %%
valid_cases=len(df[df['Class']==0])

# %%
print('Number of Valid cases : {}'.format(valid_cases))
# Out:
# Number of Valid cases : 284315

# %%
fraud=df[df['Class']==1]

# %%
valid=df[df['Class']==0]

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
valid.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# **EDA**

# %%
df.hist(figsize=(20,20),color='orange')
plt.show()

# %%
#class distribution
plt.figure(figsize=(7,5))
ax = sns.countplot(data=df,x='Class')

for bars in ax.containers:
    ax.bar_label(bars)
    
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
#Transaction Amount Distribution
plt.figure(figsize=(10,6))
sns.histplot(df['Amount'],bins=80,kde=True)
plt.title('Transaction Amount Distribution')
plt.xlabel('Amount')
plt.ylabel('Count')
plt.show()

# %%
#Fraud Vs Non-Fraud Transaction
plt.figure(figsize=(10,6))
sns.boxplot(x='Class',y='Amount',data=df)
plt.title('Transaction Amount by class')
plt.xlabel('Class')
plt.ylabel('Amount')
plt.show()

# %%
# Time Vs Amount for Fraud Transactions
fraud_transaction=df[df['Class']==1]
plt.figure(figsize=(10,6))
plt.scatter(fraud_transaction['Time'],fraud_transaction['Amount'])
plt.title('Time Vs Amount for Fraud Transactions')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.show()

# %%
#Correlation Heatmap
plt.figure(figsize=(25,20))
corr=df.corr()
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
#Density Distribution of Numerical features for Fraud and valid transaction
feature_to_plot  = ['V1','V2','V3'] #choose feature to plot

for feature in feature_to_plot:
    plt.figure(figsize=(6,8))
    sns.kdeplot(df[df['Class']==0][feature],label='Valid',shade=True)
    sns.kdeplot(df[df['Class']==1][feature],label='Fraud',shade=True)
    plt.title(f'Density distribution of {feature} by class')
    plt.xlabel(feature)
    plt.ylabel('Density')
    plt.legend()
    plt.show()

# %% [markdown]
# **Model Developement**

# %% [markdown]
# **Model-1 : Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,classification_report,roc_auc_score
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from sklearn.metrics import roc_curve, roc_auc_score
logcred=LogisticRegression()
logcred.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_log=logcred.predict(X_test)

# %%
acc_log=accuracy_score(y_test,y_pred_log)
pre_log=precision_score(y_test,y_pred_log)
recall_log=recall_score(y_test,y_pred_log)
f1s_log=f1_score(y_test,y_pred_log)
print(round(acc_log,3))
print(round(pre_log,2))
print(round(recall_log,2))
print(round(f1s_log,2))
# Out:
# 0.999
# 0.65
# 0.62
# 0.64

# %%
cmt=confusion_matrix(y_test,y_pred_log)

disp=ConfusionMatrixDisplay(confusion_matrix=cmt,
                            display_labels = [False, True])
disp.plot()
plt.grid(False)
plt.show()


tn, fp, fn, tp = confusion_matrix(y_test,y_pred_log).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)
# Out:
# True negative: 56831
# False postive: 33
# False negative: 37
# True postive: 61

# %%
y_log_pred_prob=logcred.predict_proba(X_test)[:,1]   # Class-1 probabilities
fpr,tpr,threshold=roc_curve(y_test,y_log_pred_prob) 
plt.plot(fpr,tpr)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X1=df.drop(['Class'],axis=1)
y1=df['Class']

# %%
X1_train,X1_test,y1_train,y1_test=train_test_split(X1,
                                               y1,
                                               test_size=0.2,
                                               random_state=1234)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
model1=lr.fit(X1_train,y1_train)

# %%
prediction1=model1.predict(X1_test)

# %%
from sklearn.metrics import accuracy_score
model_accuracy1=accuracy_score(y1_test,prediction1)

# %%
model_accuracy1
# Out:
# 0.9987711105649381

# %% [markdown]
# **Model-2**

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
X2=df.drop(['Class'],axis=1)
y2=df['Class']

# %%
dt=DecisionTreeRegressor()

# %%
X2_train,X2_test,y2_train,y2_test=train_test_split(X2,
                                                   y2,
                                                   test_size=0.2,
                                                   random_state=1234)

# %%
model2=dt.fit(X2_train,y2_train)

# %%
prediction2=model2.predict(X2_test)

# %%
accuracy_score(y2_test,prediction2)
# Out:
# 0.9990871107053826
